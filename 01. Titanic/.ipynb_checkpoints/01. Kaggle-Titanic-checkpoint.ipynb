# %% [markdown]
# # EDA To Prediction(feat. DieTanic)
# * Reference Kaggle Notebbok
#     * https://www.kaggle.com/ash316/eda-to-prediction-dietanic

# %% [markdown]
# * Data Discription
#     * https://www.kaggle.com/c/titanic/data

# %% [markdown]
# "Sometimes life has a cruel sense of humor, giving you the thing you always wanted at the worst time possible." - Lisa Kleypas -

# %% [markdown]
# ## Introduction

# %% [markdown]
# The Titanic Dataset is a very good dataset for begineers to start a journey in data science and participate in comptetitions in kaggle.

# %% [markdown]
# **The Objective of this notebook** is to give an idea how is the workflow in any predictive modeling problem.

# %% [markdown]
# * Objective
#     * How do we check features
#     * How do we add new features and some Machine Learning Concept
#
# He tried to  keep the notebook as basic as possible so that even newbies can understand every phase of it.

# %% [markdown]
# ### Contents of the Notebook

# %% [markdown]
# * Part1: EDA(Exploratory Data Analysis)
#     * Analysis of the Features
#     * Finding any relations or trends considering multiple features
# * Part2: Feature Engineering and Data Cleaning
#     * Add any few features
#     * Removing redundant features
#     * Converting features into suitable form for modeling

# %% [markdown]
# ## Part1: EDA(Exploratory Data Analysis)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')  # ignore deprecation warnings
# %matplotlib inline  # 노트북내 그래프 실행
# Out:
# UsageError: unrecognized arguments: # 노트북내 그래프 실행

# %%
data = pd.read_csv('./train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# PassId, Survived, Pclass, etc...

# %%
data.shape
# Out:
# (891, 12)

# %% [markdown]
# 891개의 data point와 12개의 feature

# %%
# checking for total null values

data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Dataset에서 null값 확인

# %% [markdown]
# Age 177, Cabin(배의 선실,객실) 687, Embarked 2에서 각각 null값이 존재한다.

# %% [markdown]
# *Q1. How many Survived??*

# %%
data.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize = (18, 6))
data.Survived.value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# Survival rate(생존 비율)을 데이터셋의 다른 특징들에 대해 확인해 보도록 한다.

# %% [markdown]
# ### Analysing The Features

# %% [markdown]
# ### 1) Categorical Feature

# %%
data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
# data[['Sex', 'Survived']]

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
data[['Sex', 'Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# 여성의 경우 생존 확률이 평균적으로 0.8로 나타남. 반면 남성의 경우 생존률이 0.2<br>
# 성별 생존여부를 보더라도 남성의 경우 사망이 생존보다 몇 배 높음.

# %% [markdown]
# **Reference**<br>
# Pandas-Groupby<br>
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html

# %% [markdown]
# 좌석 등급에 따른 생존율은 어떻게 될까? 하나씩 살펴보도록한다.

# %% [markdown]
# ### 2) Ordinal Feature

# %%
pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_bcde5258_9695_11ea_a353_00198600313drow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_bcde5258_9695_11ea_a353_00198600313drow0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_bcde5258_9695_11ea_a353_00198600313drow0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_bcde5258_9695_11ea_a353_00198600313drow1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_bcde5258_9695_11ea_a353_00198600313drow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_bcde5258_9695_11ea_a353_00198600313drow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_bcde5258_9695_11ea_a353_00198600313drow2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_bcde5258_9695_11ea_a353_00198600313drow2_col1 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_bcde5258_9695_11ea_a353_00198600313drow2_col2 {
#             background-color:  #90c866;
#             color:  #000000;
#         }    #T_bcde5258_9695_11ea_a353_00198600313drow3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_bcde5258_9695_11ea_a353_00198600313drow3_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_bcde5258_9695_11ea_a353_00198600313drow3_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_bcde5258_9695_11ea_a353_00198600313d" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bcde5258_9695_11ea_a353_00198600313dlevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_bcde5258_9695_11ea_a353_00198600313drow0_col0" class="data row0 col0" >80</td>
#                         <td id="T_bcde5258_9695_11ea_a353_00198600313drow0_col1" class="data row0 col1" >136</td>
#                         <td id="T_bcde5258_9695_11ea_a353_00198600313drow0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_bcde5258_9695_11ea_a353_00198600313dlevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_bcde5258_9695_11ea_a353_00198600313drow1_col0" class="data row1 col0" >97</td>
#                         <td id="T_bcde5258_9695_11ea_a353_00198600313drow1_col1" class="data row1 col1" >87</td>
#                         <td id="T_bcde5258_9695_11ea_a353_00198600313drow1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_bcde5258_9695_11ea_a353_00198600313dlevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_bcde5258_9695_11ea_a353_00198600313drow2_col0" class="data row2 col0" >372</td>
#                         <td id="T_bcde5258_9695_11ea_a353_00198600313drow2_col1" class="data row2 col1" >119</td>
#                         <td id="T_bcde5258_9695_11ea_a353_00198600313drow2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_bcde5258_9695_11ea_a353_00198600313dlevel0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_bcde5258_9695_11ea_a353_00198600313drow3_col0" class="data row3 col0" >549</td>
#                         <td id="T_bcde5258_9695_11ea_a353_00198600313drow3_col1" class="data row3 col1" >342</td>
#                         <td id="T_bcde5258_9695_11ea_a353_00198600313drow3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32', '#FFDF00', '#D3D3D3'], ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %% [markdown]
# People say **Money Can't Buy Everything.** But we can clearly see that Passenegers Of Pclass 1 were given a very high priority while rescue. Even though that the number of Passengers in Pclass 3 were a lot higher, still the number of survival from them is very low, somewhere around 25%.

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_92929e9e_9696_11ea_9ed1_00198600313drow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow1_col3 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow2_col0 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow2_col1 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow2_col2 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow2_col3 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow3_col0 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow3_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow3_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_92929e9e_9696_11ea_9ed1_00198600313drow4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_92929e9e_9696_11ea_9ed1_00198600313d" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_92929e9e_9696_11ea_9ed1_00198600313dlevel0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_92929e9e_9696_11ea_9ed1_00198600313dlevel1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow0_col0" class="data row0 col0" >3</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow0_col1" class="data row0 col1" >6</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow0_col2" class="data row0 col2" >72</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_92929e9e_9696_11ea_9ed1_00198600313dlevel1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow1_col0" class="data row1 col0" >91</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow1_col1" class="data row1 col1" >70</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow1_col2" class="data row1 col2" >72</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_92929e9e_9696_11ea_9ed1_00198600313dlevel0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_92929e9e_9696_11ea_9ed1_00198600313dlevel1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow2_col0" class="data row2 col0" >77</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow2_col1" class="data row2 col1" >91</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow2_col2" class="data row2 col2" >300</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_92929e9e_9696_11ea_9ed1_00198600313dlevel1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow3_col0" class="data row3 col0" >45</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow3_col1" class="data row3 col1" >17</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow3_col2" class="data row3 col2" >47</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_92929e9e_9696_11ea_9ed1_00198600313dlevel0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_92929e9e_9696_11ea_9ed1_00198600313dlevel1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow4_col0" class="data row4 col0" >216</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow4_col1" class="data row4 col1" >184</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow4_col2" class="data row4 col2" >491</td>
#                         <td id="T_92929e9e_9696_11ea_9ed1_00198600313drow4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# 3등석의 남자는 다 죽었구나...

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=data)
plt.show()

# %% [markdown]
# Pclass에 관계없이 여성이 더 우선적으로 살아남았다

# %% [markdown]
# ### Continous Feature

# %%
print('Oldest Passenger was of:', data['Age'].max(), 'Year')
print('Youngest Passenger was of:', data['Age'].min(), 'Year')
print('Average Age on the ship:', data['Age'].mean(), 'Year')
# Out:
# Oldest Passenger was of: 80.0 Year
# Youngest Passenger was of: 0.42 Year
# Average Age on the ship: 29.69911764705882 Year

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot("Pclass", "Age", hue="Survived", data=data, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))
sns.violinplot("Sex", "Age", hue="Survived", data=data, split=True, ax=ax[1])
ax[1].set_title("Sex and Age vs Survived")
ax[1].set_yticks(range(0, 110, 10))
plt.show()
